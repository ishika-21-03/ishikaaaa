# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\ishik\documents\custom office templates\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\ishik\documents\custom office templates\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\ishik\documents\custom office templates\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ishik\documents\custom office templates\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\ishik\documents\custom office templates\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\ishik\documents\custom office templates\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ishik\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ishik\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ishik\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ishik\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ishik\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\ishik\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
with open('food bootcamp.txt', 'r') as file:
    text = file.read()

# %%
sentences = sent_tokenize(text)
words = word_tokenize(text)

# %%
print("Sentences:", sentences)
print("Words:", words)
# Out:
# Sentences: ['Food nourishes the body and fuels daily activities.', 'It connects people, cultures, and traditions.', 'With endless flavors, food offers variety and creativity.', 'It plays a central role in celebrations and gatherings.', 'Food sustains us, providing energy and health.', 'Each meal tells a story of cultureÂ\xa0andÂ\xa0history.']
# Words: ['Food', 'nourishes', 'the', 'body', 'and', 'fuels', 'daily', 'activities', '.', 'It', 'connects', 'people', ',', 'cultures', ',', 'and', 'traditions', '.', 'With', 'endless', 'flavors', ',', 'food', 'offers', 'variety', 'and', 'creativity', '.', 'It', 'plays', 'a', 'central', 'role', 'in', 'celebrations', 'and', 'gatherings', '.', 'Food', 'sustains', 'us', ',', 'providing', 'energy', 'and', 'health', '.', 'Each', 'meal', 'tells', 'a', 'story', 'of', 'cultureÂ', 'andÂ', 'history', '.']

# %%
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.isalpha() and word not in stop_words]

# %%
print("Filtered Words:", filtered_words)
# Out:
# Filtered Words: ['Food', 'nourishes', 'body', 'fuels', 'daily', 'activities', 'It', 'connects', 'people', 'cultures', 'traditions', 'With', 'endless', 'flavors', 'food', 'offers', 'variety', 'creativity', 'It', 'plays', 'central', 'role', 'celebrations', 'gatherings', 'Food', 'sustains', 'us', 'providing', 'energy', 'health', 'Each', 'meal', 'tells', 'story', 'cultureÂ', 'andÂ', 'history']

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_words]

# %%
print("Stemmed Words:", stemmed_words)
# Out:
# Stemmed Words: ['food', 'nourish', 'bodi', 'fuel', 'daili', 'activ', 'it', 'connect', 'peopl', 'cultur', 'tradit', 'with', 'endless', 'flavor', 'food', 'offer', 'varieti', 'creativ', 'it', 'play', 'central', 'role', 'celebr', 'gather', 'food', 'sustain', 'us', 'provid', 'energi', 'health', 'each', 'meal', 'tell', 'stori', 'cultureâ', 'andâ', 'histori']

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]

# %%
print("Lemmatized Words:", lemmatized_words)
# Out:
# Lemmatized Words: ['Food', 'nourishes', 'body', 'fuel', 'daily', 'activity', 'It', 'connects', 'people', 'culture', 'tradition', 'With', 'endless', 'flavor', 'food', 'offer', 'variety', 'creativity', 'It', 'play', 'central', 'role', 'celebration', 'gathering', 'Food', 'sustains', 'u', 'providing', 'energy', 'health', 'Each', 'meal', 'tell', 'story', 'cultureÂ', 'andÂ', 'history']

# %%
from collections import Counter

word_freq = Counter(words)
print("word frequencies:", word_freq)
# Out:
# word frequencies: Counter({'.': 6, 'and': 5, ',': 4, 'Food': 2, 'It': 2, 'a': 2, 'nourishes': 1, 'the': 1, 'body': 1, 'fuels': 1, 'daily': 1, 'activities': 1, 'connects': 1, 'people': 1, 'cultures': 1, 'traditions': 1, 'With': 1, 'endless': 1, 'flavors': 1, 'food': 1, 'offers': 1, 'variety': 1, 'creativity': 1, 'plays': 1, 'central': 1, 'role': 1, 'in': 1, 'celebrations': 1, 'gatherings': 1, 'sustains': 1, 'us': 1, 'providing': 1, 'energy': 1, 'health': 1, 'Each': 1, 'meal': 1, 'tells': 1, 'story': 1, 'of': 1, 'cultureÂ': 1, 'andÂ': 1, 'history': 1})

# %%
# !pip install WordCloud
# Out:
# Requirement already satisfied: WordCloud in c:\users\ishik\documents\custom office templates\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\ishik\documents\custom office templates\lib\site-packages (from WordCloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\ishik\documents\custom office templates\lib\site-packages (from WordCloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\ishik\documents\custom office templates\lib\site-packages (from WordCloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ishik\documents\custom office templates\lib\site-packages (from matplotlib->WordCloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ishik\documents\custom office templates\lib\site-packages (from matplotlib->WordCloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ishik\documents\custom office templates\lib\site-packages (from matplotlib->WordCloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ishik\documents\custom office templates\lib\site-packages (from matplotlib->WordCloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ishik\documents\custom office templates\lib\site-packages (from matplotlib->WordCloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ishik\documents\custom office templates\lib\site-packages (from matplotlib->WordCloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ishik\documents\custom office templates\lib\site-packages (from matplotlib->WordCloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ishik\documents\custom office templates\lib\site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.16.0)

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
